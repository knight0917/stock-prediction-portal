# %%
import pandas as pd

# %%
df = pd.read_csv("call_activity_3100.csv")
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       MA             103        415                 no              no
# 1       OH             180        214                yes             yes
# 2       RI              93        646                 no              no
# 3       IN              15        404                 no              no
# 4       IN             107        312                yes             yes
# ...    ...             ...        ...                ...             ...
# 3095    NJ              46        312                 no             yes
# 3096    HI              19        404                 no             yes
# 3097    NY              68        713                yes             yes
# 3098    WY             218        619                 no             yes
# 3099    RI             102        510                 no             yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['State']
# Out:
# 0       MA
# 1       OH
# 2       RI
# 3       IN
# 4       IN
#         ..
# 3095    NJ
# 3096    HI
# 3097    NY
# 3098    WY
# 3099    RI
# Name: State, Length: 3100, dtype: object

# %%
type(df['State'])
# Out:
# pandas.core.series.Series

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    MA             103        415                 no              no
# 1    OH             180        214                yes             yes
# 2    RI              93        646                 no              no
# 3    IN              15        404                 no              no
# 4    IN             107        312                yes             yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     41             339.58              128
# 1                     31             326.31               55
# 2                     38             259.56              121
# 3                     44              97.80              105
# 4                     45              46.08              129
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             57.73             308.59               91             26.23
# ...

# %%
df.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3095    NJ              46        312                 no             yes
# 3096    HI              19        404                 no             yes
# 3097    NY              68        713                yes             yes
# 3098    WY             218        619                 no             yes
# 3099    RI             102        510                 no             yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3095                     12             145.34               19
# 3096                     25              99.24               12
# 3097                     13              99.36               76
# 3098                     30             168.80               42
# 3099                      3             251.85              138
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %% [markdown]
# # create a data frame from a dict.

# %%
tempDict = {
    'Name':['Tony','Steave','John'],
    'Designation':['Electrician','Soldier','Pirates'],
    'Salary':[100000000,100,1000000]
}

# %%
dictDf = pd.DataFrame.from_dict(tempDict)

# %%
dictDf
# Out:
#      Name  Designation     Salary
# 0    Tony  Electrician  100000000
# 1  Steave      Soldier        100
# 2    John      Pirates    1000000

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    MA             103        415                 no              no
# 1    OH             180        214                yes             yes
# 2    RI              93        646                 no              no
# 3    IN              15        404                 no              no
# 4    IN             107        312                yes             yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     41             339.58              128
# 1                     31             326.31               55
# 2                     38             259.56              121
# 3                     44              97.80              105
# 4                     45              46.08              129
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             57.73             308.59               91             26.23
# ...

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                      object
# dtype: object

# %%
df.State
# Out:
# 0       MA
# 1       OH
# 2       RI
# 3       IN
# 4       IN
#         ..
# 3095    NJ
# 3096    HI
# 3097    NY
# 3098    WY
# 3099    RI
# Name: State, Length: 3100, dtype: object

# %%
df['International plan']
# Out:
# 0        no
# 1       yes
# 2        no
# 3        no
# 4       yes
#        ...
# 3095     no
# 3096     no
# 3097    yes
# 3098     no
# 3099     no
# Name: International plan, Length: 3100, dtype: object

# %%
df[['State', 'International plan', 'Total day calls']]
# Out:
#      State International plan  Total day calls
# 0       MA                 no              128
# 1       OH                yes               55
# 2       RI                 no              121
# 3       IN                 no              105
# 4       IN                yes              129
# ...    ...                ...              ...
# 3095    NJ                 no               19
# 3096    HI                 no               12
# 3097    NY                yes               76
# 3098    WY                 no               42
# 3099    RI                 no              138
#
# [3100 rows x 3 columns]

# %%
df.State.unique()
# Out:
# array(['MA', 'OH', 'RI', 'IN', 'MO', 'WY', 'OK', 'HI', 'VA', 'NJ', 'WV',
#        'CO', 'NH', 'TX', 'LA', 'MT', 'ID', 'NY', 'IA', 'FL'], dtype=object)

# %%
df[df['International plan'] == 'no']
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       MA             103        415                 no              no
# 2       RI              93        646                 no              no
# 3       IN              15        404                 no              no
# 6       MA             189        512                 no              no
# 7       WY              21        305                 no              no
# ...    ...             ...        ...                ...             ...
# 3094    WV             188        510                 no              no
# 3095    NJ              46        312                 no             yes
# 3096    HI              19        404                 no             yes
# 3098    WY             218        619                 no             yes
# 3099    RI             102        510                 no             yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df[(df['International plan'] == 'no') & (df['Churn'] == 'no')]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 2       RI              93        646                 no              no
# 3       IN              15        404                 no              no
# 7       WY              21        305                 no              no
# 15      IN             117        718                 no              no
# 17      NH             104        718                 no             yes
# ...    ...             ...        ...                ...             ...
# 3087    NY             125        512                 no              no
# 3091    NH             203        512                 no             yes
# 3094    WV             188        510                 no              no
# 3096    HI              19        404                 no             yes
# 3098    WY             218        619                 no             yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.head(20)
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 0     MA             103        415                 no              no
# 1     OH             180        214                yes             yes
# 2     RI              93        646                 no              no
# 3     IN              15        404                 no              no
# 4     IN             107        312                yes             yes
# 5     MO              72        312                yes             yes
# 6     MA             189        512                 no              no
# 7     WY              21        305                 no              no
# 8     OK             103        407                 no             yes
# 9     HI             122        212                yes             yes
# 10    VA             211        718                yes             yes
# 11    NJ             215        206                yes              no
# ...

# %%
df.iloc[17]
# Out:
# State                         NH
# Account length               104
# Area code                    718
# International plan            no
# Voice mail plan              yes
# Number vmail messages          3
# Total day minutes         328.61
# Total day calls               72
# Total day charge           55.86
# Total eve minutes         160.82
# Total eve calls               18
# Total eve charge           13.67
# Total night minutes       276.71
# Total night calls             69
# Total night charge         12.45
# Total intl minutes           6.3
# Total intl calls               2
# Total intl charge            1.7
# Customer service calls         9
# Churn                         no
# Name: 17, dtype: object

# %%
df.iloc[17, 3] #[row, col]
# Out:
# 'no'

# %%
df.iloc[17, 7]
# Out:
# np.int64(72)

# %%
df.iloc[17, 0]
# Out:
# 'NH'

# %%
df.iloc[17, -1]
# Out:
# 'no'

# %% [markdown]
# #SLicing

# %%
df.iloc[9:20]
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 9     HI             122        212                yes             yes
# 10    VA             211        718                yes             yes
# 11    NJ             215        206                yes              no
# 12    OH              75        415                yes             yes
# 13    OK             203        305                yes              no
# 14    WV              88        718                 no              no
# 15    IN             117        718                 no              no
# 16    CO             100        202                 no              no
# 17    NH             104        718                 no             yes
# 18    OH             152        404                 no             yes
# 19    WY             131        202                 no              no
#
#     Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
state = df.copy()
state.set_index('State', inplace = True)

# %%
state.head()
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# MA                103        415                 no              no
# OH                180        214                yes             yes
# RI                 93        646                 no              no
# IN                 15        404                 no              no
# IN                107        312                yes             yes
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# MA                        41             339.58              128
# OH                        31             326.31               55
# RI                        38             259.56              121
# IN                        44              97.80              105
# IN                        45              46.08              129
#
#        Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# State
# ...

# %%
state.loc['OH']
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# OH                180        214                yes             yes
# OH                 75        415                yes             yes
# OH                152        404                 no             yes
# OH                130        503                yes              no
# OH                 65        415                yes              no
# ...               ...        ...                ...             ...
# OH                107        202                 no             yes
# OH                125        202                 no             yes
# OH                157        407                 no             yes
# OH                208        503                yes             yes
# OH                164        702                yes             yes
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# OH                        31             326.31               55
# ...

# %%
state.reset_index()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       MA             103        415                 no              no
# 1       OH             180        214                yes             yes
# 2       RI              93        646                 no              no
# 3       IN              15        404                 no              no
# 4       IN             107        312                yes             yes
# ...    ...             ...        ...                ...             ...
# 3095    NJ              46        312                 no             yes
# 3096    HI              19        404                 no             yes
# 3097    NY              68        713                yes             yes
# 3098    WY             218        619                 no             yes
# 3099    RI             102        510                 no             yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       MA             103        415                 no              no
# 1       OH             180        214                yes             yes
# 2       RI              93        646                 no              no
# 3       IN              15        404                 no              no
# 4       IN             107        312                yes             yes
# ...    ...             ...        ...                ...             ...
# 3095    NJ              46        312                 no             yes
# 3096    HI              19        404                 no             yes
# 3097    NY              68        713                yes             yes
# 3098    WY             218        619                 no             yes
# 3099    RI             102        510                 no             yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
df.drop('Total night minutes', axis=1) #axis=1 is column  axis=0 is row
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       MA             103        415                 no              no
# 1       OH             180        214                yes             yes
# 2       RI              93        646                 no              no
# 3       IN              15        404                 no              no
# 4       IN             107        312                yes             yes
# ...    ...             ...        ...                ...             ...
# 3095    NJ              46        312                 no             yes
# 3096    HI              19        404                 no             yes
# 3097    NY              68        713                yes             yes
# 3098    WY             218        619                 no             yes
# 3099    RI             102        510                 no             yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df['New Column'] = df['Total day charge'] + df['Total night charge']

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       MA             103        415                 no              no
# 1       OH             180        214                yes             yes
# 2       RI              93        646                 no              no
# 3       IN              15        404                 no              no
# 4       IN             107        312                yes             yes
# ...    ...             ...        ...                ...             ...
# 3095    NJ              46        312                 no             yes
# 3096    HI              19        404                 no             yes
# 3097    NY              68        713                yes             yes
# 3098    WY             218        619                 no             yes
# 3099    RI             102        510                 no             yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.iloc[0, -1] = 60

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       MA             103        415                 no              no
# 1       OH             180        214                yes             yes
# 2       RI              93        646                 no              no
# 3       IN              15        404                 no              no
# 4       IN             107        312                yes             yes
# ...    ...             ...        ...                ...             ...
# 3095    NJ              46        312                 no             yes
# 3096    HI              19        404                 no             yes
# 3097    NY              68        713                yes             yes
# 3098    WY             218        619                 no             yes
# 3099    RI             102        510                 no             yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.to_csv('output.csv')

# %%
df.to_json()
# Out:
# '{"State":{"0":"MA","1":"OH","2":"RI","3":"IN","4":"IN","5":"MO","6":"MA","7":"WY","8":"OK","9":"HI","10":"VA","11":"NJ","12":"OH","13":"OK","14":"WV","15":"IN","16":"CO","17":"NH","18":"OH","19":"WY","20":"WV","21":"WY","22":"VA","23":"IN","24":"TX","25":"HI","26":"RI","27":"OH","28":"LA","29":"VA","30":"MT","31":"RI","32":"MO","33":"WV","34":"MT","35":"MA","36":"OK","37":"ID","38":"MA","39":"NY","40":"NY","41":"NH","42":"RI","43":"NJ","44":"TX","45":"WY","46":"MA","47":"ID","48":"OK","49":"WY","50":"IA","51":"NH","52":"NY","53":"HI","54":"WV","55":"OK","56":"NJ","57":"IN","58":"IA","59":"OK","60":"IN","61":"MA","62":"ID","63":"RI","64":"TX","65":"NY","66":"LA","67":"NY","68":"NY","69":"WV","70":"RI","71":"OK","72":"NH","73":"LA","74":"WY","75":"IN","76":"LA","77":"TX","78":"ID","79":"RI","80":"WY","81":"IN","82":"MT","83":"NJ","84":"IN","85":"NJ","86":"MT","87":"ID","88":"RI","89":"OK","90":"WV","91":"HI","92":"MT","93":"WV","94":"FL","95":"ID","96":"TX","97":"MO","98":"RI","99":"M
# ...

# %%
df.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>State</th>\n      <th>Account length</th>\n      <th>Area code</th>\n      <th>International plan</th>\n      <th>Voice mail plan</th>\n      <th>Number vmail messages</th>\n      <th>Total day minutes</th>\n      <th>Total day calls</th>\n      <th>Total day charge</th>\n      <th>Total eve minutes</th>\n      <th>Total eve calls</th>\n      <th>Total eve charge</th>\n      <th>Total night minutes</th>\n      <th>Total night calls</th>\n      <th>Total night charge</th>\n      <th>Total intl minutes</th>\n      <th>Total intl calls</th>\n      <th>Total intl charge</th>\n      <th>Customer service calls</th>\n      <th>Churn</th>\n      <th>New Column</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>MA</td>\n      <td>103</td>\n      <td>415</td>\n      <td>no</td>\n      <td>no</td>\n      <td>41</td>\n      <td>339.58</td>\n      <td>128</t
# ...

# %%
del df

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined
